# %% [markdown]
# # Welcome to Value Added Report
# author: Jack Lau <br>
# last edit: 27/10/19 <br>
# purpose: this report is use to show the value added insight

# %%
import pandas as pd
from intopia_analysis import *

# %%
df_value = get_value_added_data('phase2/value_added/')
df_value_new = analysis_value_added_data(df_value, 2, 5)

# %% [markdown]
# # Total Value Added Analysis Report

# %%
df_value_new.sort_values(by='difference_5', ascending=False)
# Out:
# 0   Company Strategy  value_period2  value_period3  value_period4  \
# 2        46      TBA         2611.0        -5172.0       -10710.0
# 53       12      TBA       -18326.0       -46750.0       -41880.0
# 6        17      TBA         1399.0         3127.0        22225.0
# 32       48      TBA        -1679.0       -17023.0       -19205.0
# 1        28      TBA         3886.0         9870.0        17598.0
# 25        9      TBA        -1010.0         -638.0        -3803.0
# 26       45      TBA        -1044.0         5196.0          133.0
# 35       15      TBA        -2545.0        -3353.0        -2835.0
# 22       14      TBA           72.0        -3276.0         -928.0
# 10       57      TBA          857.0           96.0        -1316.0
# 38        8      TBA        -3099.0       -16870.0       -16956.0
# 52       56      TBA       -11081.0       -45411.0       -76204.0
# 4        38      TBA         2036.0       -28380.0       -59202.0
# ...
